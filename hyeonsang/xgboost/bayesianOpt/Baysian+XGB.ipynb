# %%
import hyperopt
print(hyperopt.__version__)
# Out:
# 0.2.7

# %%
import torch

# CUDA가 사용 가능한지 확인하고 디바이스 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from hyperopt import hp

xgb_search_space = {'max_depth' : hp.quniform('max_depth' , 5 , 20 , 1) ,
                    'min_child_weight' : hp.quniform('min_child_weight' , 1 , 2 , 1) ,
                    'learning_rate' : hp.uniform('learning_rate' , 0.01 , 0.3) ,
                    'colsample_bytree' : hp.uniform('colsample_bytree' , 0.5 , 1)
                    }

# %%
import xgboost
print(xgboost.__version__)
# Out:
# 2.1.1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
from xgboost import plot_importance

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/train.csv')
data = pd.read_csv('/content/test.csv')

df = df.drop('id', axis=1)
data = data.drop('id', axis=1)
print(df['class'].value_counts())
df.head(3)
# Out:
# class
# p    1705396
# e    1411549
# Name: count, dtype: int64
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     e          8.80         f           s         u                    f
# 1     p          4.51         x           h         o                    f
# 2     e          6.94         f           s         b                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               a            c          w         4.51  ...        NaN
# 1               a            c          n         4.79  ...        NaN
# 2               x            c          w         6.85  ...        NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0          NaN          w       NaN        NaN        f         f
# 1            y          o       NaN        NaN        t         z
# 2            s          n       NaN        NaN        f         f
#
#   spore-print-color habitat season
# 0               NaN       d      a
# 1               NaN       d      w
# 2               NaN       l      w
#
# [3 rows x 21 columns]

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

class SafeLabelEncoder(LabelEncoder):
    def __init__(self):
        super().__init__()
        self.classes_ = np.array([])

    def fit(self, y):
        y = y.astype(str)
        self.classes_ = np.unique(y)
        return self

    def transform(self, y):
        y = y.astype(str)
        # 새롭게 등장한 카테고리(클래스)에 대해 -1을 반환
        return np.array([self._safe_transform(val) for val in y])

    def _safe_transform(self, val):
        if val in self.classes_:
            return np.where(self.classes_ == val)[0][0]
        else:
            # 새로운 데이터에 대해 -1을 반환
            return -1

    def fit_transform(self, y):
        return self.fit(y).transform(y)

# %%
Pass = set(['cap-diameter' , 'stem-height' , 'stem-width' , 'class'])
le = SafeLabelEncoder()
for key in df.columns:
    print(key)
    if key in Pass : continue
    le.fit(df[key])
    df[key] = le.transform(df[key])
    data[key] = le.transform(data[key])
df['class'] = le.fit_transform(df['class'])
y = df['class']
X = df.drop('class', axis=1)
print(y.value_counts())
# Out:
# class
# cap-diameter
# cap-shape
# cap-surface
# cap-color
# does-bruise-or-bleed
# gill-attachment
# gill-spacing
# gill-color
# stem-height
# stem-width
# stem-root
# stem-surface
# stem-color
# veil-type
# veil-color
# has-ring
# ring-type
# spore-print-color
# habitat
# season
# class
# 1    1705396
# 0    1411549
# Name: count, dtype: int64

# %%
# X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.1 , random_state=156)
X_train , X_eval , y_train , y_eval = train_test_split(X , y , test_size=0.1 , random_state=156)

# %%
from xgboost import XGBClassifier
from hyperopt import STATUS_OK
from sklearn.model_selection import cross_val_score

def objective_func(search_space):
    xgb = XGBClassifier(
        n_estimators = 100,
        max_depth = int(search_space['max_depth']),
        min_child_weight = int(search_space['min_child_weight']),
        learning_rate = search_space['learning_rate'],
        colsample_bytree = search_space['colsample_bytree'],
        eval_metric = 'logloss',
        tree_method='gpu_hist',  # GPU 사용 설정
        use_label_encoder=False,  # XGBoost 경고 방지를 위한 설정
        n_jobs=-1  # 모든 CPU 코어 사용
    )

    accuracy = cross_val_score(xgb , X_train , y_train , scoring='accuracy' , cv = 3)

    return {'loss' : -1 * np.mean(accuracy) , 'status' : STATUS_OK}

# %%
from hyperopt import fmin , tpe , Trials

trial_val = Trials()

best = fmin(
    fn = objective_func,
    space = xgb_search_space,
    algo = tpe.suggest,
    max_evals = 50,
    trials = trial_val
)

best
# Out:
# 100%|██████████| 50/50 [29:20<00:00, 35.20s/trial, best loss: -0.9923678816124797]
# {'colsample_bytree': 0.5395317035035201,
#  'learning_rate': 0.08094810900900441,
#  'max_depth': 19.0,
#  'min_child_weight': 2.0}

# %%
xgb_wrapper = XGBClassifier(n_estimators = 400 ,
                            learning_rate = round(best['learning_rate'] , 5),
                            max_depth = int(best['max_depth']),
                            min_child_weight = int(best['min_child_weight']),
                            colsample_bytree = round(best['colsample_bytree'] , 5),
                            early_stopping_rounds=50,
                            eval_metric='logloss'
                            )


evals = [(X_train,y_train) , (X_eval , y_eval)]
xgb_wrapper.fit(X_train , y_train  , eval_set=evals , verbose=True)
# Out:
# [0]	validation_0-logloss:0.62332	validation_1-logloss:0.62329
# [1]	validation_0-logloss:0.56466	validation_1-logloss:0.56481
# [2]	validation_0-logloss:0.50921	validation_1-logloss:0.50944
# [3]	validation_0-logloss:0.46558	validation_1-logloss:0.46587
# [4]	validation_0-logloss:0.42322	validation_1-logloss:0.42367
# [5]	validation_0-logloss:0.38509	validation_1-logloss:0.38561
# [6]	validation_0-logloss:0.35349	validation_1-logloss:0.35408
# [7]	validation_0-logloss:0.32555	validation_1-logloss:0.32619
# [8]	validation_0-logloss:0.30025	validation_1-logloss:0.30096
# [9]	validation_0-logloss:0.27661	validation_1-logloss:0.27732
# [10]	validation_0-logloss:0.25441	validation_1-logloss:0.25514
# [11]	validation_0-logloss:0.23485	validation_1-logloss:0.23557
# [12]	validation_0-logloss:0.21895	validation_1-logloss:0.21966
# [13]	validation_0-logloss:0.20241	validation_1-logloss:0.20313
# [14]	validation_0-logloss:0.18812	validation_1-logloss:0.18891
# [15]	validation_0-logloss:0.17535	validation_1-logloss:0.17617
# [16]	validation_0-logloss:0.16610	validation_1-logloss:0.16689
# [17]	validation_0-logloss:0.15480	validation_1-logloss:0.15565
# [18]	validation_0-logloss:0.14486	validation_1-logloss:0.14578
# [19]	validation_0-logloss:0.13547	validation_1-logloss:0.13647
# [20]	validation_0-logloss:0.12698	validation_1-logloss:0.12806
# [21]	validation_0-logloss:0.11971	validation_1-logloss:0.12080
# [22]	validation_0-logloss:0.11235	validation_1-logloss:0.11348
# [23]	validation_0-logloss:0.10565	validation_1-logloss:0.10685
# [24]	validation_0-logloss:0.09958	validation_1-logloss:0.10080
# [25]	validation_0-logloss:0.09520	validation_1-logloss:0.09641
# [26]	validation_0-logloss:0.08986	validation_1-logloss:0.09109
# [27]	validation_0-logloss:0.08557	validation_1-logloss:0.08682
# [28]	validation_0-logloss:0.08145	validation_1-logloss:0.08277
# [29]	validation_0-logloss:0.07759	validation_1-logloss:0.07899
# [30]	validation_0-logloss:0.07388	validation_1-logloss:0.07533
# [31]	validation_0-logloss:0.07087	validation_1-logloss:0.07234
# [32]	validation_0-logloss:0.06775	validation_1-logloss:0.06930
# [33]	validation_0-logloss:0.06492	validation_1-logloss:0.06649
# [34]	validation_0-logloss:0.06217	validation_1-logloss:0.06382
# [35]	validation_0-logloss:0.05997	validation_1-logloss:0.06169
# [36]	validation_0-logloss:0.05767	validation_1-logloss:0.05947
# [37]	validation_0-logloss:0.05558	validation_1-logloss:0.05749
# [38]	validation_0-logloss:0.05349	validation_1-logloss:0.05549
# [39]	validation_0-logloss:0.05202	validation_1-logloss:0.05405
# [40]	validation_0-logloss:0.05028	validation_1-logloss:0.05243
# [41]	validation_0-logloss:0.04897	validation_1-logloss:0.05111
# [42]	validation_0-logloss:0.04775	validation_1-logloss:0.04989
# [43]	validation_0-logloss:0.04639	validation_1-logloss:0.04869
# [44]	validation_0-logloss:0.04513	validation_1-logloss:0.04757
# [45]	validation_0-logloss:0.04394	validation_1-logloss:0.04649
# [46]	validation_0-logloss:0.04303	validation_1-logloss:0.04563
# [47]	validation_0-logloss:0.04216	validation_1-logloss:0.04493
# [48]	validation_0-logloss:0.04121	validation_1-logloss:0.04409
# [49]	validation_0-logloss:0.04047	validation_1-logloss:0.04346
# [50]	validation_0-logloss:0.03982	validation_1-logloss:0.04281
# [51]	validation_0-logloss:0.03903	validation_1-logloss:0.04215
# [52]	validation_0-logloss:0.03838	validation_1-logloss:0.04162
# [53]	validation_0-logloss:0.03779	validation_1-logloss:0.04115
# [54]	validation_0-logloss:0.03718	validation_1-logloss:0.04070
# [55]	validation_0-logloss:0.03662	validation_1-logloss:0.04024
# [56]	validation_0-logloss:0.03605	validation_1-logloss:0.03976
# [57]	validation_0-logloss:0.03552	validation_1-logloss:0.03939
# [58]	validation_0-logloss:0.03509	validation_1-logloss:0.03904
# [59]	validation_0-logloss:0.03471	validation_1-logloss:0.03873
# [60]	validation_0-logloss:0.03422	validation_1-logloss:0.03843
# [61]	validation_0-logloss:0.03391	validation_1-logloss:0.03825
# [62]	validation_0-logloss:0.03360	validation_1-logloss:0.03797
# [63]	validation_0-logloss:0.03330	validation_1-logloss:0.03775
# [64]	validation_0-logloss:0.03315	validation_1-logloss:0.03761
# [65]	validation_0-logloss:0.03281	validation_1-logloss:0.03744
# [66]	validation_0-logloss:0.03244	validation_1-logloss:0.03726
# [67]	validation_0-logloss:0.03220	validation_1-logloss:0.03710
# [68]	validation_0-logloss:0.03195	validation_1-logloss:0.03697
# [69]	validation_0-logloss:0.03165	validation_1-logloss:0.03680
# [70]	validation_0-logloss:0.03147	validation_1-logloss:0.03665
# [71]	validation_0-logloss:0.03129	validation_1-logloss:0.03656
# [72]	validation_0-logloss:0.03119	validation_1-logloss:0.03646
# [73]	validation_0-logloss:0.03098	validation_1-logloss:0.03637
# [74]	validation_0-logloss:0.03067	validation_1-logloss:0.03627
# [75]	validation_0-logloss:0.03038	validation_1-logloss:0.03620
# [76]	validation_0-logloss:0.03022	validation_1-logloss:0.03613
# [77]	validation_0-logloss:0.03009	validation_1-logloss:0.03609
# [78]	validation_0-logloss:0.02980	validation_1-logloss:0.03604
# [79]	validation_0-logloss:0.02974	validation_1-logloss:0.03599
# [80]	validation_0-logloss:0.02951	validation_1-logloss:0.03594
# [81]	validation_0-logloss:0.02930	validation_1-logloss:0.03589
# [82]	validation_0-logloss:0.02910	validation_1-logloss:0.03583
# [83]	validation_0-logloss:0.02897	validation_1-logloss:0.03580
# [84]	validation_0-logloss:0.02879	validation_1-logloss:0.03577
# [85]	validation_0-logloss:0.02865	validation_1-logloss:0.03574
# [86]	validation_0-logloss:0.02849	validation_1-logloss:0.03573
# [87]	validation_0-logloss:0.02833	validation_1-logloss:0.03570
# [88]	validation_0-logloss:0.02819	validation_1-logloss:0.03566
# [89]	validation_0-logloss:0.02815	validation_1-logloss:0.03564
# [90]	validation_0-logloss:0.02803	validation_1-logloss:0.03562
# [91]	validation_0-logloss:0.02790	validation_1-logloss:0.03561
# [92]	validation_0-logloss:0.02784	validation_1-logloss:0.03559
# [93]	validation_0-logloss:0.02780	validation_1-logloss:0.03556
# [94]	validation_0-logloss:0.02770	validation_1-logloss:0.03556
# [95]	validation_0-logloss:0.02756	validation_1-logloss:0.03554
# [96]	validation_0-logloss:0.02742	validation_1-logloss:0.03552
# [97]	validation_0-logloss:0.02733	validation_1-logloss:0.03552
# [98]	validation_0-logloss:0.02722	validation_1-logloss:0.03553
# [99]	validation_0-logloss:0.02710	validation_1-logloss:0.03552
# [100]	validation_0-logloss:0.02698	validation_1-logloss:0.03552
# [101]	validation_0-logloss:0.02692	validation_1-logloss:0.03552
# [102]	validation_0-logloss:0.02674	validation_1-logloss:0.03551
# [103]	validation_0-logloss:0.02671	validation_1-logloss:0.03549
# [104]	validation_0-logloss:0.02668	validation_1-logloss:0.03549
# [105]	validation_0-logloss:0.02661	validation_1-logloss:0.03548
# [106]	validation_0-logloss:0.02646	validation_1-logloss:0.03549
# [107]	validation_0-logloss:0.02636	validation_1-logloss:0.03550
# [108]	validation_0-logloss:0.02634	validation_1-logloss:0.03549
# [109]	validation_0-logloss:0.02628	validation_1-logloss:0.03549
# [110]	validation_0-logloss:0.02621	validation_1-logloss:0.03549
# [111]	validation_0-logloss:0.02617	validation_1-logloss:0.03549
# [112]	validation_0-logloss:0.02613	validation_1-logloss:0.03550
# [113]	validation_0-logloss:0.02610	validation_1-logloss:0.03548
# [114]	validation_0-logloss:0.02599	validation_1-logloss:0.03549
# [115]	validation_0-logloss:0.02586	validation_1-logloss:0.03549
# [116]	validation_0-logloss:0.02575	validation_1-logloss:0.03549
# [117]	validation_0-logloss:0.02569	validation_1-logloss:0.03549
# [118]	validation_0-logloss:0.02561	validation_1-logloss:0.03550
# [119]	validation_0-logloss:0.02556	validation_1-logloss:0.03550
# [120]	validation_0-logloss:0.02546	validation_1-logloss:0.03550
# [121]	validation_0-logloss:0.02542	validation_1-logloss:0.03551
# [122]	validation_0-logloss:0.02533	validation_1-logloss:0.03551
# [123]	validation_0-logloss:0.02525	validation_1-logloss:0.03552
# [124]	validation_0-logloss:0.02519	validation_1-logloss:0.03553
# [125]	validation_0-logloss:0.02512	validation_1-logloss:0.03552
# [126]	validation_0-logloss:0.02504	validation_1-logloss:0.03553
# [127]	validation_0-logloss:0.02498	validation_1-logloss:0.03554
# [128]	validation_0-logloss:0.02487	validation_1-logloss:0.03555
# [129]	validation_0-logloss:0.02482	validation_1-logloss:0.03555
# [130]	validation_0-logloss:0.02479	validation_1-logloss:0.03556
# [131]	validation_0-logloss:0.02477	validation_1-logloss:0.03556
# [132]	validation_0-logloss:0.02466	validation_1-logloss:0.03556
# [133]	validation_0-logloss:0.02459	validation_1-logloss:0.03556
# [134]	validation_0-logloss:0.02454	validation_1-logloss:0.03557
# [135]	validation_0-logloss:0.02450	validation_1-logloss:0.03557
# [136]	validation_0-logloss:0.02447	validation_1-logloss:0.03556
# [137]	validation_0-logloss:0.02438	validation_1-logloss:0.03557
# [138]	validation_0-logloss:0.02432	validation_1-logloss:0.03558
# [139]	validation_0-logloss:0.02429	validation_1-logloss:0.03558
# [140]	validation_0-logloss:0.02425	validation_1-logloss:0.03559
# [141]	validation_0-logloss:0.02422	validation_1-logloss:0.03560
# [142]	validation_0-logloss:0.02415	validation_1-logloss:0.03561
# [143]	validation_0-logloss:0.02405	validation_1-logloss:0.03562
# [144]	validation_0-logloss:0.02400	validation_1-logloss:0.03562
# [145]	validation_0-logloss:0.02393	validation_1-logloss:0.03562
# [146]	validation_0-logloss:0.02389	validation_1-logloss:0.03562
# [147]	validation_0-logloss:0.02388	validation_1-logloss:0.03562
# [148]	validation_0-logloss:0.02385	validation_1-logloss:0.03563
# [149]	validation_0-logloss:0.02383	validation_1-logloss:0.03562
# [150]	validation_0-logloss:0.02379	validation_1-logloss:0.03563
# [151]	validation_0-logloss:0.02373	validation_1-logloss:0.03564
# [152]	validation_0-logloss:0.02369	validation_1-logloss:0.03564
# [153]	validation_0-logloss:0.02363	validation_1-logloss:0.03565
# [154]	validation_0-logloss:0.02360	validation_1-logloss:0.03565
# [155]	validation_0-logloss:0.02356	validation_1-logloss:0.03566
# [156]	validation_0-logloss:0.02350	validation_1-logloss:0.03566
# [157]	validation_0-logloss:0.02345	validation_1-logloss:0.03567
# [158]	validation_0-logloss:0.02339	validation_1-logloss:0.03569
# [159]	validation_0-logloss:0.02336	validation_1-logloss:0.03569
# [160]	validation_0-logloss:0.02334	validation_1-logloss:0.03570
# [161]	validation_0-logloss:0.02329	validation_1-logloss:0.03570
# [162]	validation_0-logloss:0.02326	validation_1-logloss:0.03571
# [163]	validation_0-logloss:0.02322	validation_1-logloss:0.03572
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.53953, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.08095, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=19,
#               max_leaves=None, min_child_weight=2, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=400,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
pred_probs = xgb_wrapper.predict(data)
preds = [1 if x > 0.5 else 0 for x in pred_probs]

preds[:5]
# Out:
# [0, 1, 1, 1, 0]

# %%
id = pd.read_csv('/content/test.csv')['id']

with open("result.csv", "w") as f2:
    f2.write("id,class\n")
    for i , p in zip(id , preds):

      if p == 1:
        f2.write(f"{i},p\n")
      else:
        f2.write(f"{i},e\n")
